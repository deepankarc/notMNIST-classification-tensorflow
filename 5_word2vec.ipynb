# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(0.5).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.207730
# Nearest to up: frieza, meister, mail, castlereagh, duration, employs, contestants, gs,
# Nearest to and: ingenious, precise, votes, commando, ipc, carrie, shuffled, characterization,
# Nearest to has: auras, seeger, dartmoor, brig, steamed, provincias, kaltenbrunner, efficiently,
# Nearest to its: integrated, products, qadhafi, vineyard, mudslides, renderer, futures, ewell,
# Nearest to when: bathroom, qualcomm, probing, panorama, pull, daria, schawlow, conceal,
# Nearest to use: mosaic, algorithm, arias, etymology, undercover, slightest, hugs, awakened,
# Nearest to who: scraps, fortifications, substances, verified, shameless, preferring, rumour, seanad,
# Nearest to of: emit, nessus, reentry, reductionism, hercules, seating, sravaka, drift,
# Nearest to six: fruitarians, marks, deafness, watts, regains, simulated, lowlands, plating,
# Nearest to for: refining, airstream, bucket, singh, weigh, miltiades, intercepting, telharmonium,
# Nearest to between: bodleian, solitaire, dated, underlines, hooke, minimizes, mentally, secretions,
# Nearest to one: kyanite, taliaferro, ibn, rsdlp, complexion, discharge, inkjet, lighting,
# Nearest to i: disinformation, macromedia, supercomputing, social, flung, abundances, weiss, section,
# Nearest to years: adoptionism, navy, noodles, maynard, microcomputer, keno, breve, zionists,
# Nearest to people: moller, lorne, antecedent, zeppo, functionalism, football, battlecruisers, vent,
# Nearest to about: levies, mebyon, decide, dependence, supervision, repel, jarom, sanctuary,
# Average loss at step 2000: 4.644591
# Average loss at step 4000: 4.029564
# Average loss at step 6000: 3.924823
# Average loss at step 8000: 3.870504
# Average loss at step 10000: 3.734325
# Nearest to up: mail, employs, minicomputer, blockaded, network, meister, castlereagh, solute,
# Nearest to and: or, of, in, s, for, with, from, on,
# Nearest to has: is, was, efficiently, can, lucie, probably, optic, formatted,
# Nearest to its: the, his, products, integrated, innovation, frequent, injunctions, dkw,
# Nearest to when: qualcomm, conceal, newsletter, panorama, is, chia, odd, dictate,
# Nearest to use: arias, econometric, mosaic, slightest, awakened, resh, darshan, capacitors,
# Nearest to who: verified, cowboys, folks, ginger, rumour, also, medieval, flattery,
# Nearest to of: in, and, for, nessus, with, from, pool, emit,
# Nearest to six: nine, three, zero, four, seven, marks, evaluates, deafness,
# Nearest to for: in, of, under, and, to, during, as, with,
# Nearest to between: bodleian, secretions, convinced, of, solitaire, arabidopsis, globe, hiller,
# Nearest to one: two, three, four, five, pence, f, seven, nine,
# Nearest to i: disinformation, social, weiss, sensuous, you, eg, babylon, alkanes,
# Nearest to years: earthdawn, granites, microcomputer, intimidate, navy, globe, uke, france,
# Nearest to people: moller, tala, zeppo, original, nsson, consulship, antecedent, football,
# Nearest to about: urbanisation, comnenus, earlier, sitcoms, sanctuary, jarom, volunteer, stood,
# Average loss at step 12000: 3.682289
# Average loss at step 14000: 3.705861
# Average loss at step 16000: 3.666413
# Average loss at step 18000: 3.647762
# Average loss at step 20000: 3.622224
# Nearest to up: mail, network, fullerenes, minicomputer, blockaded, annihilate, solute, employs,
# Nearest to and: or, in, s, of, who, but, from, with,
# Nearest to has: is, had, was, have, because, supp, probably, although,
# Nearest to its: the, his, their, products, her, integrated, a, innovation,
# Nearest to when: conceal, qualcomm, during, newsletter, is, chia, odd, since,
# Nearest to use: arias, slightest, econometric, mosaic, practice, resh, awakened, capacitors,
# Nearest to who: verified, and, cowboys, also, rumour, ginger, creates, they,
# Nearest to of: in, and, for, between, from, reductionism, nessus, with,
# Nearest to six: nine, four, three, seven, five, zero, eight, two,
# Nearest to for: in, during, of, to, under, with, strengths, single,
# Nearest to between: of, secretions, bodleian, to, convinced, galton, in, arabidopsis,
# Nearest to one: two, four, three, eight, seven, five, nine, six,
# Nearest to i: disinformation, you, sniper, scribes, fanciful, weiss, social, warhead,
# Nearest to years: granites, france, uke, microcomputer, earthdawn, navy, keyes, russia,
# Nearest to people: tala, moller, zeppo, those, nsson, consulship, original, warning,
# Nearest to about: urbanisation, earlier, jarom, comnenus, op, sanctuary, sitcoms, levies,
# Average loss at step 22000: 3.610453
# Average loss at step 24000: 3.524557
# Average loss at step 26000: 3.508950
# Average loss at step 28000: 3.555364
# Average loss at step 30000: 3.486975
# Nearest to up: mail, fullerenes, network, them, annihilate, minicomputer, harley, inaccurately,
# Nearest to and: or, in, who, from, including, but, edicts, for,
# Nearest to has: had, is, was, have, although, supp, because, optic,
# Nearest to its: the, their, his, her, products, sided, innovation, each,
# Nearest to when: during, conceal, if, is, took, qualcomm, chia, goidelic,
# Nearest to use: practice, arias, slightest, mosaic, econometric, awakened, resh, economy,
# Nearest to who: he, verified, never, also, rumour, and, they, cowboys,
# Nearest to of: in, reductionism, for, syndicated, between, katydids, dictum, from,
# Nearest to six: nine, eight, four, five, seven, three, two, zero,
# Nearest to for: under, during, of, intercepting, in, strengths, with, and,
# Nearest to between: secretions, convinced, of, bodleian, ethnologue, with, excuse, galton,
# Nearest to one: two, four, instruments, pp, six, pence, eight, anxiolytic,
# Nearest to i: you, disinformation, scribes, weiss, sniper, fanciful, alkanes, sensuous,
# Nearest to years: granites, uke, france, navy, keyes, russia, revue, microcomputer,
# Nearest to people: tala, those, moller, nsson, zeppo, imperator, consulship, countries,
# Nearest to about: urbanisation, jarom, sanctuary, levies, comnenus, sitcoms, earlier, op,
# Average loss at step 32000: 3.493148
# Average loss at step 34000: 3.512858
# Average loss at step 36000: 3.451696
# Average loss at step 38000: 3.560761
# Average loss at step 40000: 3.512836
# Nearest to up: mail, fullerenes, annihilate, network, them, out, readily, harley,
# Nearest to and: or, but, amused, from, edicts, anatolian, verified, who,
# Nearest to has: had, was, have, is, supp, spokane, although, creates,
# Nearest to its: their, the, his, her, our, products, innovation, affiliations,
# Nearest to when: during, if, took, conceal, is, whaling, until, but,
# Nearest to use: practice, arias, slightest, mosaic, awakened, econometric, resh, economy,
# Nearest to who: he, never, they, verified, also, rumour, she, cowboys,
# Nearest to of: reductionism, alioth, for, in, syndicated, boomers, between, subscribe,
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to for: during, in, under, of, by, homomorphism, with, while,
# Nearest to between: in, with, secretions, convinced, on, ethnologue, bodleian, coms,
# Nearest to one: two, three, six, four, seven, eight, five, pp,
# Nearest to i: you, disinformation, fanciful, usurper, sniper, sensuous, alkanes, abundances,
# Nearest to years: granites, france, uke, times, revue, keyes, navy, dryope,
# Nearest to people: tala, those, countries, imperator, moller, zeppo, nsson, resurrect,
# Nearest to about: urbanisation, levies, jarom, sitcoms, sanctuary, op, conceding, stood,
# Average loss at step 42000: 3.495973
# Average loss at step 44000: 3.363391
# Average loss at step 46000: 3.472846
# Average loss at step 48000: 3.499168
# Average loss at step 50000: 3.498345
# Nearest to up: out, mail, them, fullerenes, annihilate, meister, readily, solute,
# Nearest to and: or, but, in, blowout, when, who, fell, vary,
# Nearest to has: had, was, have, is, although, monotheists, creates, vue,
# Nearest to its: their, his, the, our, her, products, affiliations, sided,
# Nearest to when: if, during, took, until, was, although, since, and,
# Nearest to use: practice, arias, mosaic, slightest, agriculture, awakened, bonny, economy,
# Nearest to who: he, never, she, they, verified, rumour, and, also,
# Nearest to of: in, for, reductionism, including, alioth, polymerase, katydids, from,
# Nearest to six: seven, five, eight, four, nine, three, two, zero,
# Nearest to for: during, under, in, of, homomorphism, strengths, while, to,
# Nearest to between: with, in, on, ethnologue, secretions, bodleian, convinced, galton,
# Nearest to one: two, six, seven, five, four, three, eight, pp,
# Nearest to i: you, we, disinformation, fanciful, g, usurper, alkanes, swimmers,
# Nearest to years: days, times, granites, france, year, hendrick, revue, uke,
# Nearest to people: those, tala, countries, imperator, zeppo, resurrect, rehabilitated, moller,
# Nearest to about: urbanisation, levies, jarom, sanctuary, conceding, op, sitcoms, seaweed,
# Average loss at step 52000: 3.520193
# Average loss at step 54000: 3.498595
# Average loss at step 56000: 3.472903
# Average loss at step 58000: 3.359439
# Average loss at step 60000: 3.443823
# Nearest to up: out, them, readily, annihilate, solute, mail, harley, fullerenes,
# Nearest to and: or, but, including, in, syndicated, kana, who, edicts,
# Nearest to has: had, have, was, is, although, monotheists, creates, spokane,
# Nearest to its: their, his, the, our, her, affiliations, some, products,
# Nearest to when: if, during, took, before, was, after, although, until,
# Nearest to use: practice, arias, mosaic, agriculture, slightest, awakened, optimized, lingering,
# Nearest to who: he, never, she, they, also, rumour, which, cowboys,
# Nearest to of: reductionism, in, including, damme, for, syndicated, alioth, dictum,
# Nearest to six: seven, five, four, eight, three, nine, two, zero,
# Nearest to for: during, under, homomorphism, while, strengths, electoral, intercepting, when,
# Nearest to between: with, in, bodleian, ethnologue, secretions, blowout, galton, on,
# Nearest to one: two, four, six, seven, three, five, eight, pp,
# Nearest to i: you, we, fanciful, g, they, sniper, alkanes, usurper,
# Nearest to years: days, year, times, granites, months, hendrick, revue, france,
# Nearest to people: those, countries, imperator, tala, men, zeppo, u, rehabilitated,
# Nearest to about: urbanisation, jarom, levies, conceding, op, over, sanctuary, sitcoms,
# Average loss at step 62000: 3.505436
# Average loss at step 64000: 3.423661
# Average loss at step 66000: 3.414175
# Average loss at step 68000: 3.451871
# Average loss at step 70000: 3.428445
# Nearest to up: out, them, readily, annihilate, down, solute, harley, woodford,
# Nearest to and: or, but, including, edicts, syndicated, amused, glottalized, in,
# Nearest to has: had, have, was, is, although, monotheists, since, spokane,
# Nearest to its: their, his, the, her, our, affiliations, several, some,
# Nearest to when: if, during, although, until, before, while, after, where,
# Nearest to use: practice, agriculture, arias, mosaic, slightest, ais, lingering, manoeuvre,
# Nearest to who: he, never, they, she, also, valiant, which, rumour,
# Nearest to of: reductionism, in, including, for, katydids, datatypes, polymerase, lionheart,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to for: during, after, while, when, strengths, homomorphism, under, with,
# Nearest to between: with, in, bodleian, into, ethnologue, on, secretions, blowout,
# Nearest to one: two, seven, six, four, eight, three, five, nine,
# Nearest to i: you, we, ii, fanciful, they, sniper, weiss, g,
# Nearest to years: days, year, months, times, granites, revue, hendrick, dagny,
# Nearest to people: those, countries, men, imperator, tala, rehabilitated, zeppo, brahman,
# Nearest to about: urbanisation, levies, jarom, op, conceding, over, sanctuary, recoup,
# Average loss at step 72000: 3.464758
# Average loss at step 74000: 3.457351
# Average loss at step 76000: 3.420702
# Average loss at step 78000: 3.317015
# Average loss at step 80000: 3.443743
# Nearest to up: out, them, down, off, annihilate, readily, harley, solute,
# Nearest to and: or, but, including, syndicated, edicts, amused, materialize, blowout,
# Nearest to has: had, have, was, is, although, monotheists, since, makes,
# Nearest to its: their, his, the, her, our, wenham, affiliations, vendors,
# Nearest to when: if, during, although, where, until, after, while, before,
# Nearest to use: practice, agriculture, arias, mosaic, correlates, size, ais, lingering,
# Nearest to who: he, never, they, she, which, also, often, cowboys,
# Nearest to of: in, for, reductionism, including, dictum, lionheart, and, nessus,
# Nearest to six: seven, five, four, eight, three, nine, two, zero,
# Nearest to for: of, if, while, intercepting, when, homomorphism, with, during,
# Nearest to between: with, in, into, bodleian, ethnologue, on, solitaire, over,
# Nearest to one: two, seven, three, six, four, five, eight, pp,
# Nearest to i: you, we, g, ii, sniper, fanciful, limewire, finley,
# Nearest to years: days, year, months, times, granites, revue, hendrick, dagny,
# Nearest to people: those, countries, men, imperator, tala, zeppo, rehabilitated, brahman,
# Nearest to about: urbanisation, jarom, levies, conceding, over, dignified, sitcoms, afoul,
# Average loss at step 82000: 3.357372
# Average loss at step 84000: 3.404010
# Average loss at step 86000: 3.412412
# Average loss at step 88000: 3.385659
# Average loss at step 90000: 3.309940
# Nearest to up: out, them, down, off, him, annihilate, readily, solute,
# Nearest to and: or, but, including, edicts, who, plazas, amused, while,
# Nearest to has: had, have, is, was, although, since, monotheists, creates,
# Nearest to its: their, his, her, our, the, affiliations, wenham, several,
# Nearest to when: if, during, although, before, where, until, after, while,
# Nearest to use: agriculture, practice, arias, correlates, sense, mosaic, awakened, reproductive,
# Nearest to who: he, never, they, she, also, which, often, cowboys,
# Nearest to of: in, including, polymerase, datatypes, during, and, prod, katydids,
# Nearest to six: four, seven, five, eight, three, nine, two, zero,
# Nearest to for: during, after, strengths, while, by, under, if, when,
# Nearest to between: with, into, ethnologue, bodleian, among, in, solitaire, over,
# Nearest to one: two, three, seven, four, five, six, eight, pp,
# Nearest to i: you, we, g, they, limewire, ii, fanciful, sniper,
# Nearest to years: days, year, months, times, granites, decades, weeks, hendrick,
# Nearest to people: men, countries, those, imperator, tala, zeppo, rehabilitated, children,
# Nearest to about: urbanisation, levies, over, conceding, jarom, dignified, afoul, on,
# Average loss at step 92000: 2.825427
# Average loss at step 94000: 3.181435
# Average loss at step 96000: 3.125955
# Average loss at step 98000: 3.286655
# Average loss at step 100000: 3.343077
# Nearest to up: out, them, down, off, him, annihilate, solute, readily,
# Nearest to and: but, or, including, however, while, although, who, edicts,
# Nearest to has: had, have, is, was, although, monotheists, since, creates,
# Nearest to its: their, his, the, her, our, affiliations, several, wenham,
# Nearest to when: if, where, although, during, until, before, after, while,
# Nearest to use: practice, agriculture, arias, sense, correlates, mosaic, modifies, reproductive,
# Nearest to who: he, never, they, she, also, which, often, and,
# Nearest to of: reductionism, including, bodkin, polymerase, datatypes, in, for, and,
# Nearest to six: seven, four, five, eight, nine, three, zero, two,
# Nearest to for: after, by, during, while, strengths, if, in, under,
# Nearest to between: with, in, into, among, ethnologue, bodleian, solitaire, over,
# Nearest to one: two, four, seven, three, six, five, tolson, pp,
# Nearest to i: you, we, ii, they, limewire, fanciful, usurper, kibaki,
# Nearest to years: days, year, months, times, granites, decades, weeks, hendrick,
# Nearest to people: men, countries, those, imperator, tala, rehabilitated, children, zeppo,
# Nearest to about: urbanisation, levies, over, on, jarom, conceding, recoup, dignified,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
