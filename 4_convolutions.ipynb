# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = '/home/smart/Documents/Deepankar/ML/tensorflow_tutorial/notMNIST/notMNIST_large/notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.228564
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.351265
# Minibatch accuracy: 68.8%
# Validation accuracy: 50.2%
# Minibatch loss at step 100: 1.543641
# Minibatch accuracy: 56.2%
# Validation accuracy: 59.9%
# Minibatch loss at step 150: 0.734484
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 200: 0.980121
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.6%
# Minibatch loss at step 250: 1.066355
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 300: 0.489901
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 350: 0.724005
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 400: 0.829488
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 450: 0.977899
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 500: 0.686502
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 550: 0.289959
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 600: 0.590484
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 650: 0.622870
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 700: 1.125400
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 750: 0.442525
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 800: 0.434146
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 850: 0.400090
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 900: 0.685975
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 950: 0.356971
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 1000: 0.241211
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# Test accuracy: 89.8%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='VALID')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='VALID')
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.682827
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.805455
# Minibatch accuracy: 25.0%
# Validation accuracy: 41.4%
# Minibatch loss at step 100: 1.505140
# Minibatch accuracy: 50.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 150: 0.566264
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.7%
# Minibatch loss at step 200: 0.843380
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.7%
# Minibatch loss at step 250: 1.058500
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 300: 0.574974
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 350: 0.835173
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 400: 0.373736
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.5%
# Minibatch loss at step 450: 0.832190
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 500: 0.759978
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 550: 0.252055
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 600: 0.694042
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 650: 0.751757
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 700: 0.911605
# Minibatch accuracy: 56.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 750: 0.398306
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 800: 0.352231
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 850: 0.574821
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 900: 0.481452
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 950: 0.402667
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 1000: 0.231268
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Test accuracy: 90.4%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
from IPython.core.debugger import Tracer

# define dimensions
batch_size = 128
image_size = 28
filter_size = 3
channels = 1
num_filters = 64

# define hyper-parameters
hidden_layers = 2
hidden_nodes = 1024
reg = 1e-4

# define variables
conv_params = {}
fc_params = {}
conv_l2_pen = 0
fc_l2_pen = 0

# define model functions
def nn_fcnet(x, w, b):
    z = tf.matmul(x, w) + b
    return z

def nn_conv(x, w, b, strides):
    z = tf.nn.conv2d(x, w, strides=strides, padding='SAME') + b
    return z
    
def nn_relu(z):
    a = tf.nn.relu(z)
    return a

"""def nn_computeforward(a):
    # computes forward pass
    for h in xrange(hidden_layers):
        z = nn_feedforward(a, params['w%s' % (h+1)], params['b%s' %(h+1)])
        a = nn_relu(z)
    score = tf.matmul(a, params['w%s' % (hidden_layers+1)]) + params['b%s' % (hidden_layers+1)]
    
    return score"""

def model(x, conv_params, fc_params, strides=[1,1,1,1]):
    # convnet arch
    z1_conv = nn_conv(x, conv_params['w1'], conv_params['b1'], [1,1,1,1])
    a1_conv = nn_relu(z1_conv)
    z2_conv = nn_conv(a1_conv, conv_params['w2'], conv_params['b2'], strides)
    a2_conv = nn_relu(z2_conv)
    z3_conv = nn_conv(a2_conv, conv_params['w3'], conv_params['b3'], strides)
    a3_conv = nn_relu(z3_conv)
    # reshape output
    a3_shape = a3_conv.get_shape().as_list()
    a3_conv = tf.reshape(a3_conv, [a3_shape[0], a3_shape[1] * a3_shape[2] * a3_shape[3]])
    # fcnet arch
    z1 = nn_fcnet(a3_conv, fc_params['w1'], fc_params['b1'])
    a1 = nn_relu(z1)
    score = nn_fcnet(a1, fc_params['w2'], fc_params['b2'])
    
    return score

# instantiate new computational graph
new_graph = tf.Graph()
with new_graph.as_default():
    
    # declare placeholders for training data and define constants 
    # for validation and test data
    x_train = tf.placeholder(dtype=tf.float32, shape=(batch_size, image_size, image_size, channels))
    y_train = tf.placeholder(dtype=tf.float32, shape=(batch_size, num_labels))
    x_val = tf.constant(valid_dataset)
    x_test = tf.constant(test_dataset)
    global_step = tf.Variable(0, trainable=False)
    initial_lr = 0.001
    
    # model
    # convnet weights
    conv_params['w1'] = tf.Variable(
        tf.truncated_normal([filter_size, filter_size, channels, num_filters], stddev= 1. / tf.sqrt(float(batch_size))))
    conv_params['b1'] = tf.Variable(tf.zeros([num_filters]))
    conv_params['w2'] = tf.Variable(
        tf.truncated_normal([filter_size, filter_size, num_filters, 192], stddev= 1. / tf.sqrt(float(batch_size))))
    conv_params['b2'] = tf.Variable(tf.zeros([192]))
    conv_params['w3'] = tf.Variable(
        tf.truncated_normal([filter_size, filter_size, 192, 128], stddev= 1. / tf.sqrt(float(batch_size))))
    conv_params['b3'] = tf.Variable(tf.zeros([128]))
    # fully-connected net weights
    fc_params['w1'] = tf.Variable(
        tf.truncated_normal([image_size // 4 * image_size // 4 * 128, hidden_nodes]))
    fc_params['b1'] = tf.Variable(tf.zeros(hidden_nodes))
    fc_params['w2'] = tf.Variable(tf.truncated_normal([hidden_nodes, num_labels]))
    fc_params['b2'] = tf.Variable(tf.zeros(num_labels))
    
    
    score = model(x_train, conv_params, fc_params, [1,2,2,1])
    """# declare variables
    temp = np.repeat(hidden_nodes, hidden_layers)
    dims = [input_dim] + temp.tolist() + [num_labels]
    
    for h in xrange(hidden_layers+1):
        params['w%s' % (h+1)] = tf.Variable(tf.truncated_normal([dims[h], dims[h+1]]))
        params['b%s' %(h+1)] = tf.Variable(tf.zeros([dims[h+1]]))
    
    # compute forward pass
    score = nn_computeforward(x_train)"""
    
    # compute L2-penalty and cross-entropy loss
    for h in xrange(3):
        conv_l2_pen += tf.nn.l2_loss(conv_params['w%s' % (h+1)])
        if(h >= 1):
            fc_l2_pen += tf.nn.l2_loss(fc_params['w%s' % (h)])
    
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_train, logits=score) + 
                          reg*conv_l2_pen +
                          reg*fc_l2_pen)
    lr = tf.train.exponential_decay(initial_lr, global_step, 10000, 0.9, staircase=True)
    
    
    # initialise the SGD optimiser
    optimiser = tf.train.AdamOptimizer(learning_rate=lr,beta1=0.99, beta2=0.999).minimize(loss, global_step=global_step)
    
    # predictions on each dataset
    y_train_pred = tf.nn.softmax(score)
    y_val_pred = tf.nn.softmax(model(x_val, conv_params, fc_params, [1,2,2,1]))
    y_test_pred = tf.nn.softmax(model(x_test, conv_params, fc_params, [1,2,2,1]))

# %%
num_steps = 20001

with tf.Session(graph=new_graph) as new_session:

    # randomly initialise global variables
    tf.global_variables_initializer().run()
    print("Initialised")
    
    for step in xrange(num_steps):
        # generate mini-batch
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]

        # initialise the feed_dict
        feed_dict = {x_train: batch_data, y_train: batch_labels}

        # run the session
        _, l, y_pred = new_session.run([optimiser, loss, y_train_pred], feed_dict=feed_dict)

        # print the predictions after every 500 steps
        if (step % 100 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch accuracy: %.1f%%" % accuracy(y_pred, batch_labels))
            print("Validation accuracy: %.1f%%" % accuracy(y_val_pred.eval(), valid_labels))
            print("----####----")

    print("Test accuracy: %.1f%%" % accuracy(y_test_pred.eval(), test_labels))
# Out:
# Initialised
# Minibatch loss at step 0: 749.606628
# Minibatch accuracy: 10.2%
# Validation accuracy: 8.6%
# ----####----
# Minibatch loss at step 100: 244.106506
# Minibatch accuracy: 39.1%
# Validation accuracy: 41.0%
# ----####----
# Minibatch loss at step 200: 234.851288
# Minibatch accuracy: 57.0%
# Validation accuracy: 57.7%
# ----####----
# Minibatch loss at step 300: 226.075928
# Minibatch accuracy: 59.4%
# Validation accuracy: 68.1%
# ----####----
# Minibatch loss at step 400: 216.881729
# Minibatch accuracy: 73.4%
# Validation accuracy: 71.8%
# ----####----
# Minibatch loss at step 500: 208.243668
# Minibatch accuracy: 76.6%
# Validation accuracy: 74.1%
# ----####----
# Minibatch loss at step 600: 199.961121
# Minibatch accuracy: 79.7%
# Validation accuracy: 76.2%
# ----####----
# Minibatch loss at step 700: 192.109406
# Minibatch accuracy: 77.3%
# Validation accuracy: 77.9%
# ----####----
# Minibatch loss at step 800: 184.367126
# Minibatch accuracy: 75.8%
# Validation accuracy: 77.9%
# ----####----
# Minibatch loss at step 900: 177.277832
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.2%
# ----####----
# Minibatch loss at step 1000: 170.004944
# Minibatch accuracy: 83.6%
# Validation accuracy: 79.4%
# ----####----
# Minibatch loss at step 1100: 163.464447
# Minibatch accuracy: 85.9%
# Validation accuracy: 80.6%
# ----####----
# Minibatch loss at step 1200: 157.152740
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# ----####----
# Minibatch loss at step 1300: 151.176331
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.0%
# ----####----
# Minibatch loss at step 1400: 145.424713
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.1%
# ----####----
# Minibatch loss at step 1500: 139.758057
# Minibatch accuracy: 86.7%
# Validation accuracy: 81.9%
# ----####----
# Minibatch loss at step 1600: 134.680847
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.0%
# ----####----
# Minibatch loss at step 1700: 129.719315
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# ----####----
# Minibatch loss at step 1800: 124.699944
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.6%
# ----####----
# Minibatch loss at step 1900: 120.016617
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.8%
# ----####----
# Minibatch loss at step 2000: 115.464302
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.1%
# ----####----
# Minibatch loss at step 2100: 111.348701
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.0%
# ----####----
# Minibatch loss at step 2200: 106.901489
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.6%
# ----####----
# Minibatch loss at step 2300: 102.843460
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.4%
# ----####----
# Minibatch loss at step 2400: 99.015091
# Minibatch accuracy: 88.3%
# Validation accuracy: 83.6%
# ----####----
# Minibatch loss at step 2500: 95.291786
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.6%
# ----####----
# Minibatch loss at step 2600: 91.507950
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.0%
# ----####----
# Minibatch loss at step 2700: 88.128525
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.1%
# ----####----
# Minibatch loss at step 2800: 84.726166
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.8%
# ----####----
# Minibatch loss at step 2900: 81.186218
# Minibatch accuracy: 88.3%
# Validation accuracy: 84.2%
# ----####----
# Minibatch loss at step 3000: 78.114731
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.5%
# ----####----
# Minibatch loss at step 3100: 74.773407
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.5%
# ----####----
# Minibatch loss at step 3200: 71.751671
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.0%
# ----####----
# Minibatch loss at step 3300: 68.878006
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.3%
# ----####----
# Minibatch loss at step 3400: 65.997986
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.2%
# ----####----
# Minibatch loss at step 3500: 63.156677
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.5%
# ----####----
# Minibatch loss at step 3600: 60.345497
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# ----####----
# Minibatch loss at step 3700: 57.720093
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.7%
# ----####----
# Minibatch loss at step 3800: 55.122139
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# ----####----
# Minibatch loss at step 3900: 52.661957
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.2%
# ----####----
# Minibatch loss at step 4000: 50.206795
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# ----####----
# Minibatch loss at step 4100: 47.795799
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.5%
# ----####----
# Minibatch loss at step 4200: 45.584740
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.3%
# ----####----
# Minibatch loss at step 4300: 43.257866
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.1%
# ----####----
# Minibatch loss at step 4400: 41.428368
# Minibatch accuracy: 82.0%
# Validation accuracy: 87.2%
# ----####----
# Minibatch loss at step 4500: 39.402866
# Minibatch accuracy: 78.9%
# Validation accuracy: 87.6%
# ----####----
# Minibatch loss at step 4600: 37.315216
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.9%
# ----####----
# Minibatch loss at step 4700: 35.369007
# Minibatch accuracy: 83.6%
# Validation accuracy: 88.2%
# ----####----
# Minibatch loss at step 4800: 33.468994
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# ----####----
# Minibatch loss at step 4900: 31.541328
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.2%
# ----####----
# Minibatch loss at step 5000: 29.864136
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# ----####----
# Minibatch loss at step 5100: 28.115402
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.6%
# ----####----
# Minibatch loss at step 5200: 26.690382
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.7%
# ----####----
# Minibatch loss at step 5300: 25.092232
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# ----####----
# Minibatch loss at step 5400: 23.544735
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.6%
# ----####----
# Minibatch loss at step 5500: 22.152290
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# ----####----
# Minibatch loss at step 5600: 20.819643
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.2%
# ----####----
# Minibatch loss at step 5700: 19.459328
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.1%
# ----####----
# Minibatch loss at step 5800: 18.219614
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.9%
# ----####----
# Minibatch loss at step 5900: 16.950361
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# ----####----
# Minibatch loss at step 6000: 15.924795
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.9%
# ----####----
# Minibatch loss at step 6100: 14.811584
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# ----####----
# Minibatch loss at step 6200: 13.741335
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.5%
# ----####----
# Minibatch loss at step 6300: 12.919254
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.6%
# ----####----
# Minibatch loss at step 6400: 11.894318
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.5%
# ----####----
# Minibatch loss at step 6500: 11.120317
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.3%
# ----####----
# Minibatch loss at step 6600: 10.249153
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.2%
# ----####----
# Minibatch loss at step 6700: 9.490801
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
# ----####----
# Minibatch loss at step 6800: 8.837296
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.6%
# ----####----
# Minibatch loss at step 6900: 8.128933
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# ----####----
# Minibatch loss at step 7000: 7.432966
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# ----####----
# Minibatch loss at step 7100: 6.920438
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
# ----####----
# Minibatch loss at step 7200: 6.331992
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.7%
# ----####----
# Minibatch loss at step 7300: 5.744510
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# ----####----
# Minibatch loss at step 7400: 5.660862
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.8%
# ----####----
# Minibatch loss at step 7500: 4.828358
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.8%
# ----####----
# Minibatch loss at step 7600: 4.383706
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.1%
# ----####----
# Minibatch loss at step 7700: 3.981968
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.7%
# ----####----
# Minibatch loss at step 7800: 3.820247
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.0%
# ----####----
# Minibatch loss at step 7900: 3.392417
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# ----####----
# Minibatch loss at step 8000: 3.205660
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# ----####----
# Minibatch loss at step 8100: 2.927765
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# ----####----
# Minibatch loss at step 8200: 2.626757
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# ----####----
# Minibatch loss at step 8300: 2.385552
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.0%
# ----####----
# Minibatch loss at step 8400: 2.267960
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# ----####----
# Minibatch loss at step 8500: 2.059951
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# ----####----
# Minibatch loss at step 8600: 1.807336
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.2%
# ----####----
# Minibatch loss at step 8700: 1.731095
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.1%
# ----####----
# Minibatch loss at step 8800: 1.566842
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.2%
# ----####----
# Minibatch loss at step 8900: 1.429826
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 9000: 1.338228
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 9100: 1.281907
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 9200: 1.130641
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 9300: 1.088576
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 9400: 1.093414
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 9500: 1.069149
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 9600: 0.941152
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# ----####----
# Minibatch loss at step 9700: 0.868641
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 9800: 0.801351
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# ----####----
# Minibatch loss at step 9900: 0.894042
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.9%
# ----####----
# Minibatch loss at step 10000: 0.831511
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.9%
# ----####----
# Minibatch loss at step 10100: 0.703439
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# ----####----
# Minibatch loss at step 10200: 0.635506
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.2%
# ----####----
# Minibatch loss at step 10300: 0.698388
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 10400: 0.730971
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 10500: 0.638412
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 10600: 0.779992
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 10700: 0.694802
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 10800: 0.618365
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 10900: 0.556351
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 11000: 0.787958
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 11100: 0.772722
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.4%
# ----####----
# Minibatch loss at step 11200: 0.588752
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 11300: 0.670891
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 11400: 0.666095
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 11500: 0.804030
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 11600: 0.610664
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 11700: 0.542234
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.3%
# ----####----
# Minibatch loss at step 11800: 0.583752
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 11900: 0.597918
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 12000: 0.547812
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 12100: 0.545460
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 12200: 0.544430
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 12300: 0.406203
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 12400: 0.562125
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 12500: 0.637995
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 12600: 0.499708
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 12700: 0.579243
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.4%
# ----####----
# Minibatch loss at step 12800: 0.530913
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 12900: 0.468980
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 13000: 0.431687
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 13100: 0.416550
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 13200: 0.401600
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 13300: 0.430135
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 13400: 0.490726
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 13500: 0.571355
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 13600: 0.475381
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 13700: 0.475910
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.2%
# ----####----
# Minibatch loss at step 13800: 0.612884
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 13900: 0.392437
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 14000: 0.511561
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 14100: 0.485110
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 14200: 0.403880
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 14300: 0.417496
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.4%
# ----####----
# Minibatch loss at step 14400: 0.606675
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 14500: 0.459155
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 14600: 0.507637
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 14700: 0.401509
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 14800: 0.373209
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 14900: 0.425831
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 15000: 0.399082
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 15100: 0.399336
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 15200: 0.340248
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 15300: 0.502785
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 15400: 0.386821
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 15500: 0.509145
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 15600: 0.384739
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 15700: 0.433622
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 15800: 0.409200
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 15900: 0.492300
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 16000: 0.457427
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.2%
# ----####----
# Minibatch loss at step 16100: 0.384242
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 16200: 0.363700
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 16300: 0.316898
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.2%
# ----####----
# Minibatch loss at step 16400: 0.356069
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 16500: 0.338414
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 16600: 0.359624
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 16700: 0.394792
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 16800: 0.553810
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.4%
# ----####----
# Minibatch loss at step 16900: 0.420123
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 17000: 0.269104
# Minibatch accuracy: 98.4%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 17100: 0.409907
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 17200: 0.408183
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 17300: 0.336295
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.2%
# ----####----
# Minibatch loss at step 17400: 0.412311
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 17500: 0.398754
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.1%
# ----####----
# Minibatch loss at step 17600: 0.299092
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.9%
# ----####----
# Minibatch loss at step 17700: 0.334819
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 17800: 0.408942
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 17900: 0.467829
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 18000: 0.469977
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 18100: 0.313945
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 18200: 0.312340
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 18300: 0.351105
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 18400: 0.457583
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 18500: 0.353279
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# ----####----
# Minibatch loss at step 18600: 0.342731
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 18700: 0.366753
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# ----####----
# Minibatch loss at step 18800: 0.314974
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 18900: 0.398503
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 19000: 0.349021
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.4%
# ----####----
# Minibatch loss at step 19100: 0.409514
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# ----####----
# Minibatch loss at step 19200: 0.406992
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 19300: 0.382900
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.7%
# ----####----
# Minibatch loss at step 19400: 0.397292
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# ----####----
# Minibatch loss at step 19500: 0.300745
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 19600: 0.311316
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.1%
# ----####----
# Minibatch loss at step 19700: 0.358542
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 19800: 0.276594
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# ----####----
# Minibatch loss at step 19900: 0.421750
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.0%
# ----####----
# Minibatch loss at step 20000: 0.306342
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.0%
# ----####----
# Test accuracy: 96.1%
